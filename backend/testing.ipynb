# %%
from invokeagent import return_dictionary, write_extracted_information
from tools.extractJSON import rewrite_report_for_llm
from tools.writefuelmeter import write_fuel_meter_sheet
from tools.write_electronic_sales import write_electronic_sales_sheet

# %%
test_input = """
26th August 2026
      Pump 1
PMS:1696506.241
PMS:674346.474
AG0:852073.232
AGO:545945.489

      PUMP 2
PMs:1387009.991
PMS. 346458.312
AGO:446305.630
AGO:292880.765

   STOCK
PMS: 9305.26
AGo:8000

     LOSS AND GAIN
PMS  -7
AGO. +5
TOTAL SALES
PMS: 1620.885
AGO:946.91


  LPG SALES:
6kg  (1)60000, burner (1)17000
     LUBES SALES  :  Gtx ½L (1)10000,GTX 1L(3)57000,GTX 4L (3)2160000, power  1(5)80000  coolant (1)18000,Edge w40 4L (1)190000, Edge w40 1L (1)50000, Edge w30 1L (1)55000, Magnetic 4L (1)125000,Multi 1L (5)100000, multi 5L (4)380000, filter 1001(1)8000
 Expenses:
 Tp to Bank 2000,
 ELECTRONIC SALES:
Airtel money :1055808
Visa card:585000
Rubis card: 604200
Rubis App : 
Top up:

BANKING 15,622,000

Water presence 
Pms: little drops
Ago: little drops
Bik: Unmeasured droops
"""

# %%
output_dict = return_dictionary(test_input)

# %%
print(len(output_dict))
# Out:
# 2

# %%
output_dict[0]
# Out:
# {'date': '2026-08-26',
#  'pumps': {'PMS 1': {'opening': 1696506.241, 'closing': 674346.474},
#   'PMS 2': {'opening': 1387009.991, 'closing': 346458.312}},
#  'rtt': {'PMS': -7, 'AGO': 5}}

# %%
output_dict[1]
# Out:
# {'date': '2026-08-26',
#  'electronic_sales': {'MOMOPAY': None,
#   'AIRTEL': 1055808,
#   'VISA CARD': 585000,
#   'RUBIS CARD': 604200,
#   'RUBIS APP': None}}

# %%
print(output_dict)
# Out:
# [{'date': '2026-08-26', 'pumps': {'PUMP 1': {'opening': 1696506.241, 'closing': 674346.474}, 'PUMP 2': {'opening': 1387009.991, 'closing': 346458.312}}, 'rtt': {'PMS': -7, 'AGO': 5}}, {'date': '2026-08-26', 'electronic_sales': {'MOMOPAY': None, 'AIRTEL': 1055808, 'VISA CARD': 585000, 'RUBIS CARD': 604200, 'RUBIS APP': None}}]
